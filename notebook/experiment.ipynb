# %%
ls
# Out:
#  Volume in drive C is ACER
#  Volume Serial Number is 6C53-C6D1
#
#  Directory of C:\projects\telco-churn-prediction\data\raw
#
# 22-04-2026  12:34    <DIR>          .
# 22-04-2026  12:08    <DIR>          ..
# 22-04-2026  12:34           977,501 WA_Fn-UseC_-Telco-Customer-Churn.csv
#                1 File(s)        977,501 bytes
#                2 Dir(s)  270,425,473,024 bytes free

# %%
cd telco-churn-prediction\data\raw
# Out:
# C:\Projects\telco-churn-prediction\data\raw

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# pip install

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df['Churn'].value_counts()
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df['customerID'].head()
df['customerID'].nunique()
# Out:
# 7043

# %%
pd.crosstab(df['gender'], df['Churn'], normalize='index')
# Out:
# Churn         No       Yes
# gender
# Female  0.730791  0.269209
# Male    0.738397  0.261603

# %%
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
df['Partner'].value_counts()
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
pd.crosstab(df['Partner'], df['Churn'], normalize='index')
# Out:
# Churn          No       Yes
# Partner
# No       0.670420  0.329580
# Yes      0.803351  0.196649

# %%
df['tenure'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
sns.histplot(df['tenure'], bins=30, kde=True)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
print(df['PhoneService'].value_counts())
print(df['MultipleLines'].value_counts())
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
pd.crosstab(df['OnlineSecurity'], df['Churn'], normalize='index')
# Out:
# Churn                      No       Yes
# OnlineSecurity
# No                   0.582333  0.417667
# No internet service  0.925950  0.074050
# Yes                  0.853888  0.146112

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df['MonthlyCharges'].describe()
sns.histplot(df['MonthlyCharges'], bins=30, kde=True)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>
